# %% [markdown]
# # <center >CS6700: Reinforcement Learning
# ## <center >Programming Assignment 2
# ## <center> DQN \& AC: Part 4 - AC Cartpole
# ###  Submitted by:
# ### Gautham Govind A: EE19B022
# ### Vishnu Vinod: CS19B048

# %% [markdown]
# ## Importing Libraries

# %%
'''
Installing packages for rendering the game on Colab
'''
# !pip install gym pyvirtualdisplay > /dev/null 2>&1
# !apt-get install -y xvfb python-opengl ffmpeg > /dev/null 2>&1
# !apt-get update > /dev/null 2>&1
# !apt-get install cmake > /dev/null 2>&1
# !pip install --upgrade setuptools 2>&1
# !pip install ez_setup > /dev/null 2>&1
# !pip install gym[atari] > /dev/null 2>&1
# !pip install git+https://github.com/tensorflow/docs > /dev/null 2>&1
# !pip install gym[classic_control]
# Out:
# Requirement already up-to-date: setuptools in /home/vishnu/.local/lib/python3.8/site-packages (67.6.0)
# ^C
# Requirement already satisfied: gym[classic_control] in /home/vishnu/.local/lib/python3.8/site-packages (0.26.2)
#   Ignoring pygame: markers 'extra == "classic-control"' don't match your environment
# Requirement already satisfied: numpy>=1.18.0 in /home/vishnu/.local/lib/python3.8/site-packages (from gym[classic_control]) (1.21.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/vishnu/.local/lib/python3.8/site-packages (from gym[classic_control]) (2.2.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /home/vishnu/.local/lib/python3.8/site-packages (from gym[classic_control]) (0.0.8)
# Requirement already satisfied: importlib-metadata>=4.8.0; python_version < "3.10" in /home/vishnu/.local/lib/python3.8/site-packages (from gym[classic_control]) (6.0.0)
# Requirement already satisfied: zipp>=0.5 in /home/vishnu/.local/lib/python3.8/site-packages (from importlib-metadata>=4.8.0; python_version < "3.10"->gym[classic_control]) (3.12.0)

# %%
import scipy
import numpy as np
import random
import torch
import torch.nn as nn  
import torch.nn.functional as F
from collections import namedtuple, deque
import torch.optim as optim
import datetime
import gym
from gym.wrappers.record_video import RecordVideo
import glob
import io
import base64
import matplotlib.pyplot as plt
from IPython.display import HTML
from pyvirtualdisplay import Display
import tensorflow as tf
from IPython import display as ipythondisplay
from PIL import Image
import tensorflow_probability as tfp
import seaborn as sns
from tqdm import tqdm
# Out:
# 2023-03-24 23:46:12.007545: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-24 23:46:13.398747: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/vishnu/.local/lib/python3.8/site-packages/cv2/../../lib64:
# 2023-03-24 23:46:13.398827: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/vishnu/.local/lib/python3.8/site-packages/cv2/../../lib64:
# 2023-03-24 23:46:13.398833: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %% [markdown]
# ## CartPole-v1

# %%
env = gym.make('CartPole-v1')

state_shape = env.observation_space.shape[0]
no_of_actions = env.action_space.n

print(state_shape, no_of_actions)
print(env.action_space.sample())
# Out:
# 4 2
# 0

# %% [markdown]
# ## AC Model

# %% [markdown]
# **Actor-Critic methods** learn both a policy $\pi(a|s;\theta)$ and a state-value function $v(s;w)$ simultaneously. The policy is referred to as the actor that suggests actions given a state. The estimated value function is referred to as the critic. It evaluates actions taken by the actor based on the given policy. In this exercise, both functions are approximated by feedforward neural networks.
#
# - The policy network is parametrized by $\theta$ - it takes a state $s$ as input and outputs the probabilities $\pi(a|s;\theta)\ \forall\ a$
# - The value network is parametrized by $w$ - it takes a state $s$ as input and outputs a scalar value associated with the state, i.e., $v(s;w)$
#
# - **NOTE: Here, weights of the first two hidden layers are shared by the policy and the value network**
#     - Default hidden layer sizes: [1024, 512]
#     - Output size of policy network: 2 (Softmax activation)
#     - Output size of value network: 1 (Linear activation)
#
# $$\pi(a|s;\theta) = \phi_{\theta}(a,s)$$

# %%
class ActorCriticModel(tf.keras.Model):
    """
    Defining policy and value networkss
    """
    def __init__(self, action_size, n_hidden1=1024, n_hidden2=512):
        super(ActorCriticModel, self).__init__()

        #Hidden Layer 1
        self.fc1 = tf.keras.layers.Dense(n_hidden1, activation='relu')
        #Hidden Layer 2
        self.fc2 = tf.keras.layers.Dense(n_hidden2, activation='relu')
        
        #Output Layer for policy
        self.pi_out = tf.keras.layers.Dense(action_size, activation='softmax')
        #Output Layer for state-value
        self.v_out = tf.keras.layers.Dense(1)

    def call(self, state):
        """
        Computes policy distribution and state-value for a given state
        """
        layer1 = self.fc1(state)
        layer2 = self.fc2(layer1)

        pi = self.pi_out(layer2)       # policy network outputs
        v = self.v_out(layer2)         # value network outputs

        return pi, v

# %% [markdown]
# ## Agent 1: One-Step AC

# %% [markdown]
# - The single step TD error can be defined as follows:
# $$\delta_t  = R_{t+1} + \gamma v(s_{t+1};w) - v(s_t;w)$$
#
# - The loss function to be minimized at every step ($L_{tot}^{(t)}$) is a summation of two terms, as follows:
# $$L_{tot}^{(t)} = L_{actor}^{(t)} + L_{critic}^{(t)}$$
# where,
# $$L_{actor}^{(t)} = -\log\pi(a_t|s_t; \theta)\delta_t$$
# $$L_{critic}^{(t)} = \delta_t^2$$

# %%
class Agent1:
    """
    Agent class
    """
    def __init__(self, action_size, lr=1e-4, gamma=0.99, seed = 85, h1 = 1024, h2 = 512):
        self.gamma = gamma
        self.ac_model = ActorCriticModel(action_size, h1, h2)
        self.ac_model.compile(tf.keras.optimizers.Adam(learning_rate=lr))
        np.random.seed(seed)
    
    # Given a state, compute the policy distribution over all actions and sample one action
    def sample_action(self, state):
        pi,_ = self.ac_model(state)
        action_probabilities = tfp.distributions.Categorical(probs=pi)
        sample = action_probabilities.sample()
        return int(sample.numpy()[0])

    # actor loss
    def actor_loss(self, action, pi, delta):
        return -tf.math.log(pi[0,action]) * delta

    # critic loss
    def critic_loss(self,delta):
        return delta**2

    @tf.function
    # For a given transition (s,a,s',r) update the paramters
    def learn(self, state, action, reward, next_state, done):
        with tf.GradientTape(persistent=True) as tape:
            pi, V_s = self.ac_model(state)
            _, V_s_next = self.ac_model(next_state)

            V_s = tf.squeeze(V_s)
            V_s_next = tf.squeeze(V_s_next)
            

            # Equation for TD error
            delta = reward + self.gamma*V_s_next - V_s
            loss_a = self.actor_loss(action, pi, delta)
            loss_c =self.critic_loss(delta)
            loss_total = loss_a + loss_c

        gradient = tape.gradient(loss_total, self.ac_model.trainable_variables)
        self.ac_model.optimizer.apply_gradients(zip(gradient, self.ac_model.trainable_variables))

# %%
class OneStepAC:
    def __init__(self, env_name, exp_name, eps = 2500, runs = 10, lr = 1e-4, h1 = 1024, h2 = 512):
        self.env = gym.make(env_name)
        self.state = self.env.reset()[0]
        self.thresh = 195.0
        self.lr = lr
        self.h1 = h1
        self.h2 = h2
        
        self.num_runs = runs
        self.num_eps = eps
        self.avg_steps = []
        self.avg_reward = []
        self.var_reward = []
        
        self.eps_to_solve = [self.num_eps]*self.num_runs
        self.solved = False
        
        self.start_time = None
        self.end_time = None
        self.exp_name = exp_name
        
    def train(self, verbose = 1):
        self.start_time = datetime.datetime.now()
        for run in range(self.num_runs):
            agent = Agent1(lr = self.lr, action_size = self.env.action_space.n, h1 = self.h1, h2 = self.h2)
            eps_rewards, eps_steps = [], []
            self.solved = False
            
            if verbose: print('Starting RUN:', run+1)
                
            for ep in range(1, self.num_eps+1):
                steps, rewards = 0, 0
                state = self.env.reset()[0].reshape(1,-1)
                done = False
                
                while not done:
                    action = agent.sample_action(state)
                    n_state, rew, done, info, _ = self.env.step(action)
                    n_state = n_state.reshape(1,-1)
                    
                    agent.learn(state, action, rew, n_state, done)
                    state = n_state
                    
                    rewards += rew
                    steps += 1
                
                eps_rewards.append(rewards)
                eps_steps.append(steps)

                if ep%10==0 and verbose>1: 
                    print('\r','Ep', ep, 'Avg Reward: %f'%np.mean(eps_rewards[-10:]), end='')
                    
                if ep%100 and not self.solved:
                    avg_100 = np.mean(eps_rewards[-100:])
                    if avg_100 > self.thresh:
                        self.eps_to_solve[run] = ep - 100 if ep > 100 else ep
                        self.solved = True
                        if verbose:
                            print('\nEnvironment solved in {:d} episodes!'.format(self.eps_to_solve[run]))
                            print('Env. Threshold:{:.2f} \tAverage Score: {:.2f}'.format(self.thresh, np.mean(eps_rewards[-100:])))
                        break
                        
            if self.solved:
                avg_100 = np.mean(eps_rewards[-100:])
                while len(eps_rewards)<self.num_eps:
                    eps_rewards.append(avg_100)
                
            if verbose: 
                print('Solved:', self.solved)
        
            self.avg_reward.append(eps_rewards)
            self.avg_steps.append(eps_steps)
            
        self.end_time = datetime.datetime.now()
        if verbose: print('Time Taken', self.end_time - self.start_time)
            
    def plot_results(self):
        sns.set_style("darkgrid")
        maxlen = min(max(self.eps_to_solve) + 100, 2500)
        minlen = min(min(self.eps_to_solve) + 99, 2500)
        reward_list = np.mean(self.avg_reward, axis = 0)[:maxlen]
        avg100_reward = np.array([np.mean(reward_list[max(0,i-100):i]) for i in range(1,len(reward_list)+1)])[:maxlen]

        
        print('Average Number of Episodes To Solve the Environment:', np.mean(self.eps_to_solve))
    
        plt.xlabel('Episode')
        plt.ylabel('Total Episode Reward')
        plt.title('Rewards vs Episodes: Avg Reward: %.3f'%np.mean(reward_list))
        plt.plot(np.arange(maxlen), reward_list, 'b')
        plt.plot(np.arange(maxlen), avg100_reward, 'r', linewidth=2.5)
        plt.savefig('./plots/ac_cp_'+self.exp_name+'_rewards.jpg', pad_inches = 0)
        plt.show()
        
        plt.xlabel('Episode')
        plt.ylabel('Variance by Episode')
        plt.title('Variance across Runs')
        plt.plot(np.arange(minlen), np.var(self.avg_reward, axis = 0)[:minlen], 'b')
        plt.savefig('./plots/ac_cp_'+self.exp_name+'_variance.jpg', pad_inches = 0)
        plt.show()
        
        return self.eps_to_solve, self.avg_reward

# %% [markdown]
# ## HyperParameter Tuning

# %% [markdown]
# In order to obtain the best results we need to tune the following hyperparameters:
#
# - **Learning Rate ($\alpha$)**:
# The learning rate controls how fast the model will learn. A learning rate that is too small will prove to be extremely slow while learning and is generally not useful. Similarly, a learning rate that is too high will cause huge jumps in values causing the model to overshoot the optimum parameters in the multi-dimensional parameter space. This will cause unpredictable and oscillatory behaviour of the model.
#
# For our purposes we will explore $lr \in [0.0005, 0.0001, 0.00005]$
#
# - **Hidden Layers ($h_1$ & $h_2$)**:
# The hidden layer sizes in the model greatly affect the performance of the AC model. The ability of the model to learn specific actions (overfitting on the action space) and general patterns of actions depedns on size and number of hidden layers.
#
# For our purposes we will explore $(h1, h2) \in [(512, 256), (1024, 512), (2048, 1024)]$

# %% [markdown]
# ### Experiment 1: $lr = 0.0001, h_1 = 512, h_2 = 256$
#
# First we try out a very simple configuration of hyperparameters.

# %%
trainer = OneStepAC(env_name = 'CartPole-v1', exp_name = 'e1', lr = 0.0001, h1 = 512, h2 = 256)
trainer.train(verbose = 2)
# Out:
# Starting RUN: 1
#  Ep 530 Avg Reward: 2729.800000
# Environment solved in 430 episodes!
# Env. Threshold:195.00 	Average Score: 403.31
# Solved: True
# Starting RUN: 2
#  Ep 330 Avg Reward: 329.100000
# Environment solved in 231 episodes!
# Env. Threshold:195.00 	Average Score: 195.76
# Solved: True
# Starting RUN: 3
#  Ep 480 Avg Reward: 233.000000
# Environment solved in 389 episodes!
# Env. Threshold:195.00 	Average Score: 197.11
# Solved: True
# Starting RUN: 4
#  Ep 400 Avg Reward: 208.000000
# Environment solved in 304 episodes!
# Env. Threshold:195.00 	Average Score: 195.08
# Solved: True
# Starting RUN: 5
#  Ep 460 Avg Reward: 273.300000
# Environment solved in 366 episodes!
# Env. Threshold:195.00 	Average Score: 195.19
# Solved: True
# Starting RUN: 6
#  Ep 390 Avg Reward: 260.200000
# Environment solved in 293 episodes!
# Env. Threshold:195.00 	Average Score: 207.02
# Solved: True
# Starting RUN: 7
#  Ep 500 Avg Reward: 298.900000
# Environment solved in 401 episodes!
# Env. Threshold:195.00 	Average Score: 197.02
# Solved: True
# Starting RUN: 8
#  Ep 280 Avg Reward: 423.800000
# Environment solved in 188 episodes!
# Env. Threshold:195.00 	Average Score: 195.41
# Solved: True
# Starting RUN: 9
#  Ep 450 Avg Reward: 242.900000
# Environment solved in 356 episodes!
# Env. Threshold:195.00 	Average Score: 195.72
# Solved: True
# Starting RUN: 10
#  Ep 370 Avg Reward: 153.300000
# Environment solved in 279 episodes!
# Env. Threshold:195.00 	Average Score: 200.53
# Solved: True
# Time Taken 1:08:15.750397

# %%
eps1, rew1 = trainer.plot_results()
# Out:
# Average Number of Episodes To Solve the Environment: 323.7
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 eps1, rew1 = trainer.plot_results()
#
# Cell In[42], line 102, in OneStepAC.plot_results(self)
#      99 plt.savefig('./plots/ac_cp_'+self.exp_name+'_variance.jpg', pad_inches = 0)
#     100 plt.show()
# --> 102 return self.eps_to_solve, self.self.avg_reward
#
# AttributeError: 'OneStepAC' object has no attribute 'self'

# %% [markdown]
# ### Experiment 2: $lr = 0.0001, h_1 = 1024, h_2 = 512$
#
# Now we try to increase the size of the model by changing the size of the hidden layer.

# %%
trainer = OneStepAC(env_name = 'CartPole-v1', exp_name = 'e2', lr = 0.0001, h1 = 1024, h2 = 512)
trainer.train(verbose = 2)
# Out:
# Starting RUN: 1
#  Ep 320 Avg Reward: 152.400000
# Environment solved in 226 episodes!
# Env. Threshold:195.00 	Average Score: 200.09
# Solved: True
# Starting RUN: 2
#  Ep 270 Avg Reward: 371.000000
# Environment solved in 171 episodes!
# Env. Threshold:195.00 	Average Score: 214.67
# Solved: True
# Starting RUN: 3
#  Ep 200 Avg Reward: 175.900000
# Environment solved in 102 episodes!
# Env. Threshold:195.00 	Average Score: 198.20
# Solved: True
# Starting RUN: 4
#  Ep 250 Avg Reward: 141.600000
# Environment solved in 154 episodes!
# Env. Threshold:195.00 	Average Score: 219.33
# Solved: True
# Starting RUN: 5
#  Ep 270 Avg Reward: 247.300000
# Environment solved in 173 episodes!
# Env. Threshold:195.00 	Average Score: 198.11
# Solved: True
# Starting RUN: 6
#  Ep 230 Avg Reward: 209.400000
# Environment solved in 134 episodes!
# Env. Threshold:195.00 	Average Score: 195.33
# Solved: True
# Starting RUN: 7
#  Ep 320 Avg Reward: 191.700000
# Environment solved in 224 episodes!
# Env. Threshold:195.00 	Average Score: 198.56
# Solved: True
# Starting RUN: 8
#  Ep 310 Avg Reward: 200.000000
# Environment solved in 218 episodes!
# Env. Threshold:195.00 	Average Score: 218.27
# Solved: True
# Starting RUN: 9
#  Ep 230 Avg Reward: 284.800000
# Environment solved in 131 episodes!
# Env. Threshold:195.00 	Average Score: 242.70
# Solved: True
# Starting RUN: 10
#  Ep 260 Avg Reward: 363.700000
# Environment solved in 160 episodes!
# Env. Threshold:195.00 	Average Score: 204.94
# Solved: True
# Time Taken 0:50:29.458975

# %%
eps2, rew2 = trainer.plot_results()
# Out:
# Average Number of Episodes To Solve the Environment: 169.3

# %% [markdown]
# ### Experiment 3: $lr = 0.0001, h_1 = 2048, h_2 = 1024$

# %%
trainer = OneStepAC(env_name = 'CartPole-v1', exp_name = 'e3', lr = 0.0001, h1 = 2048, h2 = 1024)
trainer.train(verbose = 2)
# Out:
# Starting RUN: 1
#  Ep 130 Avg Reward: 495.500000
# Environment solved in 39 episodes!
# Env. Threshold:195.00 	Average Score: 253.60
# Solved: True
# Starting RUN: 2
#  Ep 310 Avg Reward: 223.600000
# Environment solved in 214 episodes!
# Env. Threshold:195.00 	Average Score: 196.95
# Solved: True
# Starting RUN: 3
#  Ep 240 Avg Reward: 183.900000
# Environment solved in 148 episodes!
# Env. Threshold:195.00 	Average Score: 199.64
# Solved: True
# Starting RUN: 4
#  Ep 2500 Avg Reward: 216.600000Solved: False
# Starting RUN: 5
#  Ep 130 Avg Reward: 356.100000
# Environment solved in 31 episodes!
# Env. Threshold:195.00 	Average Score: 208.21
# Solved: True
# Starting RUN: 6
#  Ep 170 Avg Reward: 518.500000
# Environment solved in 76 episodes!
# Env. Threshold:195.00 	Average Score: 197.33
# Solved: True
# Starting RUN: 7
#  Ep 170 Avg Reward: 427.500000
# Environment solved in 72 episodes!
# Env. Threshold:195.00 	Average Score: 199.85
# Solved: True
# Starting RUN: 8
#  Ep 150 Avg Reward: 323.800000
# Environment solved in 53 episodes!
# Env. Threshold:195.00 	Average Score: 195.65
# Solved: True
# Starting RUN: 9
#  Ep 100 Avg Reward: 190.200000
# Environment solved in 3 episodes!
# Env. Threshold:195.00 	Average Score: 196.01
# Solved: True
# Starting RUN: 10
#  Ep 210 Avg Reward: 192.400000
# Environment solved in 117 episodes!
# Env. Threshold:195.00 	Average Score: 198.26
# Solved: True
# Time Taken 0:54:29.754737

# %%
eps3, rew3 = trainer.plot_results()
# Out:
# Average Number of Episodes To Solve the Environment: 325.3

# %% [markdown]
# ### Experiment 4: $lr = 0.0005, h_1 = 1024, h_2 = 512$

# %%
trainer = OneStepAC(env_name = 'CartPole-v1', exp_name = 'e4', lr = 0.0005, h1 = 1024, h2 = 512)
trainer.train(verbose = 2)
# Out:
# Starting RUN: 1
#  Ep 120 Avg Reward: 337.600000
# Environment solved in 21 episodes!
# Env. Threshold:195.00 	Average Score: 202.24
# Solved: True
# Starting RUN: 2
#  Ep 2500 Avg Reward: 9.200000Solved: False
# Starting RUN: 3
#  Ep 2500 Avg Reward: 9.200000Solved: False
# Starting RUN: 4
#  Ep 2500 Avg Reward: 9.500000Solved: False
# Starting RUN: 5
#  Ep 2500 Avg Reward: 9.000000Solved: False
# Starting RUN: 6
#  Ep 2500 Avg Reward: 9.500000Solved: False
# Starting RUN: 7
#  Ep 2500 Avg Reward: 9.400000Solved: False
# Starting RUN: 8
#  Ep 2500 Avg Reward: 9.100000Solved: False
# Starting RUN: 9
#  Ep 2500 Avg Reward: 9.700000Solved: False
# Starting RUN: 10
#  Ep 2500 Avg Reward: 9.600000Solved: False
# Time Taken 1:00:44.515017

# %%
eps4, rew4 = trainer.plot_results()
# Out:
# Average Number of Episodes To Solve the Environment: 2252.1

# %% [markdown]
# ### Experiment 5: $lr = 0.00005,  h_1 = 1024, h_2 = 512$

# %%
trainer = OneStepAC(env_name = 'CartPole-v1', exp_name = 'e5', lr = 0.00005, h1 = 1024, h2 = 512)
trainer.train(verbose = 2)
# Out:
# Starting RUN: 1
#  Ep 560 Avg Reward: 153.800000
# Environment solved in 466 episodes!
# Env. Threshold:195.00 	Average Score: 197.31
# Solved: True
# Starting RUN: 2
#  Ep 640 Avg Reward: 333.900000
# Environment solved in 542 episodes!
# Env. Threshold:195.00 	Average Score: 195.36
# Solved: True
# Starting RUN: 3
#  Ep 300 Avg Reward: 374.300000
# Environment solved in 204 episodes!
# Env. Threshold:195.00 	Average Score: 199.11
# Solved: True
# Starting RUN: 4
#  Ep 410 Avg Reward: 271.100000
# Environment solved in 313 episodes!
# Env. Threshold:195.00 	Average Score: 199.36
# Solved: True
# Starting RUN: 5
#  Ep 360 Avg Reward: 244.700000
# Environment solved in 265 episodes!
# Env. Threshold:195.00 	Average Score: 195.44
# Solved: True
# Starting RUN: 6
#  Ep 560 Avg Reward: 368.200000
# Environment solved in 463 episodes!
# Env. Threshold:195.00 	Average Score: 215.50
# Solved: True
# Starting RUN: 7
#  Ep 400 Avg Reward: 251.300000
# Environment solved in 307 episodes!
# Env. Threshold:195.00 	Average Score: 198.08
# Solved: True
# Starting RUN: 8
#  Ep 570 Avg Reward: 366.200000
# Environment solved in 475 episodes!
# Env. Threshold:195.00 	Average Score: 207.42
# Solved: True
# Starting RUN: 9
#  Ep 570 Avg Reward: 197.900000
# Environment solved in 473 episodes!
# Env. Threshold:195.00 	Average Score: 196.90
# Solved: True
# Starting RUN: 10
#  Ep 570 Avg Reward: 243.400000
# Environment solved in 477 episodes!
# Env. Threshold:195.00 	Average Score: 196.31
# Solved: True
# Time Taken 1:25:22.652622

# %%
eps5, rew5 = trainer.plot_results()
# Out:
# Average Number of Episodes To Solve the Environment: 398.5

# %% [markdown]
# ## Agent 2: Full-Return AC
#
# - The full return step TD error can be defined as follows:
# $$\delta_t^{(T)}  = \sum_{t'=t}^T \gamma^{t'-t}R_{t'+1} - v(s_t)$$
#
# - The loss function to be minimized at every step ($L_{tot}$) is a summation of two terms, as follows:
# $$L_{tot} = L_{actor} + L_{critic}$$
# where,
# $$L_{actor} = -\sum_{t=1}^T \log\pi(a_t|s_t; \theta)\delta_t^{(T)}$$
# $$L_{critic} = \sum_{t=1}^T \delta_t^{(T)^2}$$
#
# - The best hyperparameters from the previous case has been used here to prepare a comparison of the 3 AC methods.

# %%
class Agent2:
    """
    Agent class
    """
    def __init__(self, action_size, lr=1e-4, gamma=0.99, seed = 85, h1 = 1024, h2 = 512):
        self.gamma = gamma
        self.ac_model = ActorCriticModel(action_size, h1, h2)
        self.ac_model.compile(tf.keras.optimizers.Adam(learning_rate=lr))
        np.random.seed(seed)
    
    # Given a state, compute the policy distribution over all actions and sample one action
    def sample_action(self, state):
        pi,_ = self.ac_model(state)
        action_probabilities = tfp.distributions.Categorical(probs=pi)
        sample = action_probabilities.sample()
        return int(sample.numpy()[0])

    # actor loss
    def actor_loss(self, action, pi, delta):
        return -tf.math.log(pi[0,action]) * delta

    # critic loss
    def critic_loss(self,delta):
        return delta**2

    @tf.function
    # For a given transition (s,a,s',r) update the paramters
    def learn(self, state, action, target):
        with tf.GradientTape(persistent=True) as tape:
            pi, V_s = self.ac_model(state)
            V_s = tf.squeeze(V_s)

            # Equation for TD error
            delta = target - V_s
            loss_a = self.actor_loss(action, pi, delta)
            loss_c =self.critic_loss(delta)
            loss_total = loss_a + loss_c

        gradient = tape.gradient(loss_total, self.ac_model.trainable_variables)
        self.ac_model.optimizer.apply_gradients(zip(gradient, self.ac_model.trainable_variables))

# %%
class FullReturnAC:
    def __init__(self, env_name, exp_name, gamma = 0.99, eps = 2500, runs = 10, lr = 1e-4, h1 = 1024, h2 = 512):
        self.env = gym.make(env_name)
        self.state = self.env.reset()[0]
        self.thresh = 195.0
        self.max_steps = 500
        self.gamma = gamma
        self.lr = lr
        self.h1 = h1
        self.h2 = h2
        
        self.num_runs = runs
        self.num_eps = eps
        self.avg_steps = []
        self.avg_reward = []
        self.var_reward = []
        
        self.eps_to_solve = [self.num_eps]*self.num_runs
        self.solved = False
        
        self.start_time = None
        self.end_time = None
        self.exp_name = exp_name
        
    def train(self, verbose = 1):
        self.start_time = datetime.datetime.now()
        tf.compat.v1.reset_default_graph()
        for run in range(self.num_runs):
            agent = Agent2(lr = self.lr, action_size = self.env.action_space.n, h1 = self.h1, h2 = self.h2)
            eps_rewards, eps_steps = [], []
            self.solved = False
            
            if verbose: print('Starting RUN:', run+1)
                
            for ep in range(1, self.num_eps+1):
                steps, rewards = 0, 0
                state = self.env.reset()[0].reshape(1,-1)
                action_list, state_list = [], []
                step_rewards = []
                done = False
                
                print(ep)
                for steps in tqdm(range(self.max_steps)):
                    action = agent.sample_action(state)
                    state_list.append(state)
                    action_list.append(action)
                    
                    n_state, rew, done, info, _ = self.env.step(action)
                    n_state = n_state.reshape(1,-1)
                    
                    rewards += rew
                    step_rewards.append(rew)
                    
                    state = n_state
                    steps += 1
                    
                    if done or steps == self.max_steps - 1:
                        eps_rewards.append(rewards)
                        eps_steps.append(steps)
                        break
                
                for t in range(len(step_rewards)):
                    target = 0
                    for k in range(t, len(step_rewards) - 1):
                        target += (self.gamma**(k-t)) * step_rewards[k+1]
                    agent.learn(state_list[t], action_list[t], target)

                if ep%10==0 and verbose>1: 
                    print('\r','Ep', ep, 'Avg Reward: %f'%np.mean(eps_rewards[-10:]), end='')
                    
                if ep%100 and not self.solved:
                    avg_100 = np.mean(eps_rewards[-100:])
                    if avg_100 > self.thresh:
                        self.eps_to_solve[run] = ep - 100 if ep > 100 else ep
                        self.solved = True
                        if verbose:
                            print('\nEnvironment solved in {:d} episodes!'.format(self.eps_to_solve[run]))
                            print('Env. Threshold:{:.2f} \tAverage Score: {:.2f}'.format(self.thresh, np.mean(eps_rewards[-100:])))
                        break
                        
            if self.solved:
                avg_100 = np.mean(eps_rewards[-100:])
                while len(eps_rewards)<self.num_eps:
                    eps_rewards.append(avg_100)
                
            if verbose: 
                print('Solved:', self.solved)
        
            self.avg_reward.append(eps_rewards)
            self.avg_steps.append(eps_steps)
            
        self.end_time = datetime.datetime.now()
        if verbose: print('Time Taken', self.end_time - self.start_time)
            
    def plot_results(self):
        sns.set_style("darkgrid")
        maxlen = min(max(self.eps_to_solve) + 100, 2500)
        minlen = min(min(self.eps_to_solve) + 99, 2500)
        reward_list = np.mean(self.avg_reward, axis = 0)[:maxlen]
        avg100_reward = np.array([np.mean(reward_list[max(0,i-100):i]) for i in range(1,len(reward_list)+1)])[:maxlen]

        
        print('Average Number of Episodes To Solve the Environment:', np.mean(self.eps_to_solve))
    
        plt.xlabel('Episode')
        plt.ylabel('Total Episode Reward')
        plt.title('Rewards vs Episodes: Avg Reward: %.3f'%np.mean(reward_list))
        plt.plot(np.arange(maxlen), reward_list, 'b')
        plt.plot(np.arange(maxlen), avg100_reward, 'r', linewidth=2.5)
        plt.savefig('./plots/ac_cp_'+self.exp_name+'_rewards.jpg', pad_inches = 0)
        plt.show()
        
        plt.xlabel('Episode')
        plt.ylabel('Variance by Episode')
        plt.title('Variance across Runs')
        plt.plot(np.arange(minlen), np.var(self.avg_reward, axis = 0)[:minlen], 'b')
        plt.savefig('./plots/ac_cp_'+self.exp_name+'_variance.jpg', pad_inches = 0)
        plt.show()
        
        return self.eps_to_solve, self.avg_reward

# %%
trainer = FullReturnAC(env_name = 'CartPole-v1', exp_name = 'e6', lr = 0.0001, h1 = 1024, h2 = 512)
trainer.train(verbose = 1)
# Out:
# Starting RUN: 1
# 1
#   1%|▋                                                                                | 4/500 [03:21<6:56:41, 50.41s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[81], line 2
#       1 trainer = FullReturnAC(env_name = 'CartPole-v1', exp_name = 'e6', lr = 0.0001, h1 = 1024, h2 = 512)
# ----> 2 trainer.train(verbose = 1)
#
# Cell In[80], line 44, in FullReturnAC.train(self, verbose)
#      42 print(ep)
#      43 for steps in tqdm(range(self.max_steps)):
# ---> 44     action = agent.sample_action(state)
#      45     state_list.append(state)
#      46     action_list.append(action)
#
# Cell In[69], line 13, in Agent2.sample_action(self, state)
#      12 def sample_action(self, state):
# ---> 13     pi,_ = self.ac_model(state)
#      14     action_probabilities = tfp.distributions.Categorical(probs=pi)
#      15     sample = action_probabilities.sample()
#
# File ~/.local/lib/python3.8/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.local/lib/python3.8/site-packages/keras/engine/training.py:561, in Model.__call__(self, *args, **kwargs)
#     557         super().__call__(inputs, *copied_args, **copied_kwargs)
#     559     layout_map_lib._map_subclass_model_variable(self, self._layout_map)
# --> 561 return super().__call__(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.local/lib/python3.8/site-packages/keras/engine/base_layer.py:1132, in Layer.__call__(self, *args, **kwargs)
#    1127     inputs = self._maybe_cast_inputs(inputs, input_list)
#    1129 with autocast_variable.enable_auto_cast_variables(
#    1130     self._compute_dtype_object
#    1131 ):
# -> 1132     outputs = call_fn(inputs, *args, **kwargs)
#    1134 if self._activity_regularizer:
#    1135     self._handle_activity_regularization(inputs, outputs)
#
# File ~/.local/lib/python3.8/site-packages/keras/utils/traceback_utils.py:96, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      94 bound_signature = None
#      95 try:
# ---> 96     return fn(*args, **kwargs)
#      97 except Exception as e:
#      98     if hasattr(e, "_keras_call_info_injected"):
#      99         # Only inject info for the innermost failing call
#
# Cell In[4], line 26, in ActorCriticModel.call(self, state)
#      23 layer2 = self.fc2(layer1)
#      25 pi = self.pi_out(layer2)       # policy network outputs
# ---> 26 v = self.v_out(layer2)         # value network outputs
#      28 return pi, v
#
# File ~/.local/lib/python3.8/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.local/lib/python3.8/site-packages/keras/engine/base_layer.py:1132, in Layer.__call__(self, *args, **kwargs)
#    1127     inputs = self._maybe_cast_inputs(inputs, input_list)
#    1129 with autocast_variable.enable_auto_cast_variables(
#    1130     self._compute_dtype_object
#    1131 ):
# -> 1132     outputs = call_fn(inputs, *args, **kwargs)
#    1134 if self._activity_regularizer:
#    1135     self._handle_activity_regularization(inputs, outputs)
#
# File ~/.local/lib/python3.8/site-packages/keras/utils/traceback_utils.py:96, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      94 bound_signature = None
#      95 try:
# ---> 96     return fn(*args, **kwargs)
#      97 except Exception as e:
#      98     if hasattr(e, "_keras_call_info_injected"):
#      99         # Only inject info for the innermost failing call
#
# File ~/.local/lib/python3.8/site-packages/keras/layers/core/dense.py:241, in Dense.call(self, inputs)
#     237         outputs = tf.nn.embedding_lookup_sparse(
#     238             self.kernel, ids, weights, combiner="sum"
#     239         )
#     240     else:
# --> 241         outputs = tf.matmul(a=inputs, b=self.kernel)
#     242 # Broadcast kernel to inputs.
#     243 else:
#     244     outputs = tf.tensordot(inputs, self.kernel, [[rank - 1], [0]])
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:1176, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1174 # Fallback dispatch system (dispatch v1):
#    1175 try:
# -> 1176   return dispatch_target(*args, **kwargs)
#    1177 except (TypeError, ValueError):
#    1178   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1179   # TypeError, when given unexpected types.  So we need to catch both.
#    1180   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/ops/math_ops.py:3714, in matmul(a, b, transpose_a, transpose_b, adjoint_a, adjoint_b, a_is_sparse, b_is_sparse, output_type, name)
#    3711   return gen_math_ops.batch_mat_mul_v3(
#    3712       a, b, adj_x=adjoint_a, adj_y=adjoint_b, Tout=output_type, name=name)
#    3713 else:
# -> 3714   return gen_math_ops.mat_mul(
#    3715       a, b, transpose_a=transpose_a, transpose_b=transpose_b, name=name)
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/ops/gen_math_ops.py:6014, in mat_mul(a, b, transpose_a, transpose_b, name)
#    6012 if tld.is_eager:
#    6013   try:
# -> 6014     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    6015       _ctx, "MatMul", name, a, b, "transpose_a", transpose_a, "transpose_b",
#    6016       transpose_b)
#    6017     return _result
#    6018   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:
